# %%
import pandas as pd
df = pd.read_csv('/projectnb/ssmsvi/rsenne/data_marmoset/marmoset_data.csv.gz')
df_h = df[(df['name']=='Helios') & (df['stage']=='70-30')]
print('Columns:', df_h.columns.tolist())
print()
print('choice values:', df_h['choice'].unique())
# print('correct_side values:', df_h['correct_side'].unique())
# print()
# # Show a few rows
# print(df_h[['session_datetime','choice','correct_side','flashes_left','flashes_right','rt']].head(10).to_string())
# print()
# # Check accuracy using the data's own coding
# print('Accuracy (choice == correct_side):', (df_h['choice'] == df_h['correct_side']).mean())
# print()
# Out:
# Columns: ['name', 'specie', 'group', 'stage', 'sex', 'session_datetime', 'trial_datetime', 'trial', 'choice', 'outcome', 'rt', 'correct_side', 'flashes_left', 'flashes_right', 'numflashleft', 'numflashright', 'probflashleft', 'probflashright', 'flash_bins', 'init_time']
#
# choice values: ['right' 'left']

# %%
sum(df_h.outcome == "correct") / (sum(df_h.outcome == "error") + sum(df_h.outcome == "correct"))
# Out:
# 0.5644590495449949
